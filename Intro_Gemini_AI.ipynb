# %%
# -*- coding: utf-8 -*-
"""intro_gemini_ai

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1lUSP_fJCCZ1aQw-NOV6MVXWSp0TOeBwf
"""
# Out:
# 'intro_gemini_ai\n\nAutomatically generated by Colab.\n\nOriginal file is located at\n    https://colab.research.google.com/drive/1lUSP_fJCCZ1aQw-NOV6MVXWSp0TOeBwf\n'

# %%
# Commented out IPython magic to ensure Python compatibility.
# %pip install -U -q "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai
from google.colab import userdata
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
model = genai.GenerativeModel('models/gemini-2.0-flash')
response = model.generate_content("Please give me python code to sort a list.")
print(response.text)
# Out:
# ```python
# def sort_list(input_list):
#   """
#   Sorts a list using the built-in `sorted()` function.
#
#   Args:
#     input_list: The list to be sorted.
#
#   Returns:
#     A new list containing the sorted elements of the input list.
#   """
#   return sorted(input_list)
#
# # Example usage:
# my_list = [5, 2, 8, 1, 9, 4]
# sorted_list = sort_list(my_list)
# print(f"Original list: {my_list}")
# print(f"Sorted list: {sorted_list}")
#
#
# # In-place sorting (modifies the original list) using the `.sort()` method:
# my_list = [5, 2, 8, 1, 9, 4]
# my_list.sort()  # Modifies my_list directly
# print(f"Original list after in-place sorting: {my_list}")
#
# # Sorting in reverse order:
# my_list = [5, 2, 8, 1, 9, 4]
# sorted_list_reverse = sorted(my_list, reverse=True) # using sorted()
# print(f"Sorted list in reverse order using sorted(): {sorted_list_reverse}")
#
# my_list = [5, 2, 8, 1, 9, 4]
# my_list.sort(reverse=True) # using sort() in-place
# ...

# %%
from google import genai
from google.genai import types
client = genai.Client(api_key="GOOGLE_API_KEY") # Assuming GOOGLE_API_KEY is a string literal.  If it's an environment variable, use os.environ

# %%
from IPython.display import display, Markdown
image = Image.open(img_path)
image.thumbnail([512,512])

display(Markdown(response.text))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-571a43d92981> in <cell line: 0>()
#       1 from IPython.display import display, Markdown
# ----> 2 image = Image.open(img_path)
#       3 image.thumbnail([512,512])
#       4
#       5 display(Markdown(response.text))
#
# NameError: name 'Image' is not defined
